# %%
import pyarma as pa
import numpy as np
import matplotlib.pyplot as plt

# %%
#IMPORT THE RESULTS

data1 = pa.mat() 
data1.load('specificheat40.csv') 

#data2 = pa.mat() 
#data2.load('test_60.csv') 

data3 = pa.mat() 
data3.load('specificheat60.csv') 

data4 = pa.mat() 
data4.load('specificheat100.csv') 

#data5 = pa.mat() 
#data5.load('test_120.csv') 

#ARRANGE LISTS FOR PLOTTING

Tdata1 = []; Qdata1 = [];

for i in range(len(data1)):
    if i < round(len(data1)/2):
        Tdata1.append(data1[i])
    else:
        Qdata1.append(data1[i])

#Tdata2 = []; Qdata2 = [];

#for i in range(len(data2)):
#    if i < round(len(data2)/2):
#        Tdata2.append(data2[i])
#    else:
#        Qdata2.append(data2[i])
        

Tdata3 = []; Qdata3 = [];

for i in range(len(data3)):
    if i < round(len(data3)/2):
        Tdata3.append(data3[i])
    else:
        Qdata3.append(data3[i])

Tdata4 = []; Qdata4 = [];

for i in range(len(data4)):
    if i < round(len(data4)/2):
        Tdata4.append(data4[i])
    else:
        Qdata4.append(data4[i])
        

#Tdata5 = []; Qdata5 = [];

#for i in range(len(data5)):
#    if i < round(len(data5)/2):
#        Tdata5.append(data5[i])
#    else:
#        Qdata5.append(data5[i])

        
#PLOT THE RESULTS
        
plt.figure(figsize=(9, 6))
plt.rcParams.update({'font.size': 20})
linestyle='dashed'

plt.plot(Tdata1,Qdata1, label='L=40', linestyle=linestyle, linewidth=1.5, color='cornflowerblue')
#plt.plot(Tdata2, Qdata2, label='L=60', color='black')
plt.plot(Tdata3,Qdata3, label='L=60', linestyle=linestyle, linewidth=1.5, color='royalblue')
plt.plot(Tdata4,Qdata4, label='L=100', linestyle=linestyle, linewidth=1.5, color='midnightblue')
#plt.plot(Tdata5,Qdata5, label='L=120', color='red')

plt.legend(); plt.xlabel('T$[J/k_B]$'); plt.ylabel('$C_v [k_B]$')
plt.savefig('MC20000_nonfinescan.pdf')

# %%
#IMPORT THE RESULTS

data1 = pa.mat() 
data1.load('test_40.csv') 

data2 = pa.mat() 
data2.load('test_60.csv') 

data3 = pa.mat() 
data3.load('test_80.csv') 

data4 = pa.mat() 
data4.load('test_100.csv') 

#data5 = pa.mat() 
#data5.load('test_120.csv') 

#ARRANGE LISTS FOR PLOTTING

Tdata1 = []; Qdata1 = [];

for i in range(len(data1)):
    if i < round(len(data1)/2):
        Tdata1.append(data1[i])
    else:
        Qdata1.append(data1[i])

Tdata2 = []; Qdata2 = [];

for i in range(len(data2)):
    if i < round(len(data2)/2):
        Tdata2.append(data2[i])
    else:
        Qdata2.append(data2[i])
        

Tdata3 = []; Qdata3 = [];

for i in range(len(data3)):
    if i < round(len(data3)/2):
        Tdata3.append(data3[i])
    else:
        Qdata3.append(data3[i])

Tdata4 = []; Qdata4 = [];

for i in range(len(data4)):
    if i < round(len(data4)/2):
        Tdata4.append(data4[i])
    else:
        Qdata4.append(data4[i])
        

#Tdata5 = []; Qdata5 = [];

#for i in range(len(data5)):
#    if i < round(len(data5)/2):
#        Tdata5.append(data5[i])
#    else:
#        Qdata5.append(data5[i])

        
#PLOT THE RESULTS
        
plt.figure(figsize=(9, 6))
plt.rcParams.update({'font.size': 20})
linestyle='dashed'

plt.plot(Tdata1,Qdata1, label='L=40', linestyle=linestyle, linewidth=1.5, color='cornflowerblue')
plt.plot(Tdata2, Qdata2, label='L=60', linestyle=linestyle, linewidth=1.5, color='royalblue')
plt.plot(Tdata3,Qdata3, label='L=80', linestyle=linestyle, linewidth=1.5, color='midnightblue')
plt.plot(Tdata4,Qdata4, label='L=100', linestyle=linestyle, linewidth=1.5, color='black')
#plt.plot(Tdata5,Qdata5, label='L=120', color='red')

plt.legend(); plt.xlabel('T$[J/k_B]$'); plt.ylabel('$C_v [k_B]$')
plt.savefig('MC20000_finescan.pdf')

# %%
#IMPORT THE RESULTS

data1 = pa.mat() 
data1.load('test_40.csv') 

data2 = pa.mat() 
data2.load('test_60.csv') 

data3 = pa.mat() 
data3.load('test_80.csv') 

data4 = pa.mat() 
data4.load('test_100.csv') 

#data5 = pa.mat() 
#data5.load('test_120.csv') 

#ARRANGE LISTS FOR PLOTTING

Tdata1 = []; Qdata1 = [];

for i in range(len(data1)):
    if i < round(len(data1)/2):
        Tdata1.append(data1[i])
    else:
        Qdata1.append(data1[i])

Tdata2 = []; Qdata2 = [];

for i in range(len(data2)):
    if i < round(len(data2)/2):
        Tdata2.append(data2[i])
    else:
        Qdata2.append(data2[i])
        

Tdata3 = []; Qdata3 = [];

for i in range(len(data3)):
    if i < round(len(data3)/2):
        Tdata3.append(data3[i])
    else:
        Qdata3.append(data3[i])

Tdata4 = []; Qdata4 = [];

for i in range(len(data4)):
    if i < round(len(data4)/2):
        Tdata4.append(data4[i])
    else:
        Qdata4.append(data4[i])
        

#Tdata5 = []; Qdata5 = [];

#for i in range(len(data5)):
#    if i < round(len(data5)/2):
#        Tdata5.append(data5[i])
#    else:
#        Qdata5.append(data5[i])

        
#PLOT THE RESULTS
        
plt.figure(figsize=(9, 6))
plt.rcParams.update({'font.size': 20})
linestyle='dashed'

plt.plot(Tdata1,Qdata1, label='L=40', linestyle=linestyle, linewidth=1.5, color='cornflowerblue')
plt.plot(Tdata2, Qdata2, label='L=60', linestyle=linestyle, linewidth=1.5, color='royalblue')
plt.plot(Tdata3,Qdata3, label='L=80', linestyle=linestyle, linewidth=1.5, color='midnightblue')
plt.plot(Tdata4,Qdata4, label='L=100', linestyle=linestyle, linewidth=1.5, color='black')
#plt.plot(Tdata5,Qdata5, label='L=120', color='red')

plt.legend(); plt.xlabel('T$[J/k_B]$'); plt.ylabel('$C_v [k_B]$')
plt.savefig('MC30000_finescan.pdf')

# %% [markdown]
# **IMPORTANT**

# %%
#IMPORT THE RESULTS

data1 = pa.mat() 
data1.load('energy40.csv') 

data2 = pa.mat() 
data2.load('energy60.csv') 

data3 = pa.mat() 
data3.load('energy80.csv') 

data4 = pa.mat() 
data4.load('energy100.csv') 

#data5 = pa.mat() 
#data5.load('test_120.csv') 

#ARRANGE LISTS FOR PLOTTING

Tdata1 = []; Qdata1 = [];

for i in range(len(data1)):
    if i < round(len(data1)/2):
        Tdata1.append(data1[i])
    else:
        Qdata1.append(data1[i])

Tdata2 = []; Qdata2 = [];

for i in range(len(data2)):
    if i < round(len(data2)/2):
        Tdata2.append(data2[i])
    else:
        Qdata2.append(data2[i])
        

Tdata3 = []; Qdata3 = [];

for i in range(len(data3)):
    if i < round(len(data3)/2):
        Tdata3.append(data3[i])
    else:
        Qdata3.append(data3[i])

Tdata4 = []; Qdata4 = [];

for i in range(len(data4)):
    if i < round(len(data4)/2):
        Tdata4.append(data4[i])
    else:
        Qdata4.append(data4[i])
        

#Tdata5 = []; Qdata5 = [];

#for i in range(len(data5)):
#    if i < round(len(data5)/2):
#        Tdata5.append(data5[i])
#    else:
#        Qdata5.append(data5[i])

        
#PLOT THE RESULTS
        
plt.figure(figsize=(9, 6))
plt.rcParams.update({'font.size': 20})
linestyle='dashed'

plt.plot(Tdata1,Qdata1, label='L=40', linestyle=linestyle, linewidth=1.5, color='cornflowerblue')
plt.plot(Tdata2, Qdata2, label='L=60', linestyle=linestyle, linewidth=1.5, color='royalblue')
plt.plot(Tdata3,Qdata3, label='L=80', linestyle=linestyle, linewidth=1.5, color='midnightblue')
plt.plot(Tdata4,Qdata4, label='L=100', linestyle=linestyle, linewidth=1.5, color='black')
#plt.plot(Tdata5,Qdata5, label='L=120', color='red')

plt.legend(); plt.xlabel('T$[J/k_B]$'); plt.ylabel('Average energy [J]')
plt.savefig('MC500000_average_energy.pdf')

# %%
#IMPORT THE RESULTS

data1 = pa.mat() 
data1.load('magnetism40.csv') 

data2 = pa.mat() 
data2.load('magnetism60.csv') 

data3 = pa.mat() 
data3.load('magnetism80.csv') 

data4 = pa.mat() 
data4.load('magnetism100.csv') 

#data5 = pa.mat() 
#data5.load('test_120.csv') 

#ARRANGE LISTS FOR PLOTTING

Tdata1 = []; Qdata1 = [];

for i in range(len(data1)):
    if i < round(len(data1)/2):
        Tdata1.append(data1[i])
    else:
        Qdata1.append(data1[i])

Tdata2 = []; Qdata2 = [];

for i in range(len(data2)):
    if i < round(len(data2)/2):
        Tdata2.append(data2[i])
    else:
        Qdata2.append(data2[i])
        

Tdata3 = []; Qdata3 = [];

for i in range(len(data3)):
    if i < round(len(data3)/2):
        Tdata3.append(data3[i])
    else:
        Qdata3.append(data3[i])

Tdata4 = []; Qdata4 = [];

for i in range(len(data4)):
    if i < round(len(data4)/2):
        Tdata4.append(data4[i])
    else:
        Qdata4.append(data4[i])
        

#Tdata5 = []; Qdata5 = [];

#for i in range(len(data5)):
#    if i < round(len(data5)/2):
#        Tdata5.append(data5[i])
#    else:
#        Qdata5.append(data5[i])

        
#PLOT THE RESULTS
        
plt.figure(figsize=(9, 6))
plt.rcParams.update({'font.size': 20})
linestyle='dashed'

plt.plot(Tdata1,Qdata1, label='L=40', linestyle=linestyle, linewidth=1.5, color='cornflowerblue')
plt.plot(Tdata2, Qdata2, label='L=60', linestyle=linestyle, linewidth=1.5, color='royalblue')
plt.plot(Tdata3,Qdata3, label='L=80', linestyle=linestyle, linewidth=1.5, color='midnightblue')
plt.plot(Tdata4,Qdata4, label='L=100', linestyle=linestyle, linewidth=1.5, color='black')
#plt.plot(Tdata5,Qdata5, label='L=120', color='red')

plt.legend(); plt.xlabel('T$[J/k_B]$'); plt.ylabel('Average Magnetization')
plt.savefig('MC500000_finescan_average_magnetization.pdf')

# %%
#IMPORT THE RESULTS

data1 = pa.mat() 
data1.load('susceptibility40.csv') 

data2 = pa.mat() 
data2.load('susceptibility60.csv') 

data3 = pa.mat() 
data3.load('susceptibility80.csv') 

data4 = pa.mat() 
data4.load('susceptibility100.csv') 

#data5 = pa.mat() 
#data5.load('test_120.csv') 

#ARRANGE LISTS FOR PLOTTING

Tdata1 = []; Qdata1 = [];

for i in range(len(data1)):
    if i < round(len(data1)/2):
        Tdata1.append(data1[i])
    else:
        Qdata1.append(data1[i])

Tdata2 = []; Qdata2 = [];

for i in range(len(data2)):
    if i < round(len(data2)/2):
        Tdata2.append(data2[i])
    else:
        Qdata2.append(data2[i])
        

Tdata3 = []; Qdata3 = [];

for i in range(len(data3)):
    if i < round(len(data3)/2):
        Tdata3.append(data3[i])
    else:
        Qdata3.append(data3[i])

Tdata4 = []; Qdata4 = [];

for i in range(len(data4)):
    if i < round(len(data4)/2):
        Tdata4.append(data4[i])
    else:
        Qdata4.append(data4[i])
        

#Tdata5 = []; Qdata5 = [];

#for i in range(len(data5)):
#    if i < round(len(data5)/2):
#        Tdata5.append(data5[i])
#    else:
#        Qdata5.append(data5[i])

        
#PLOT THE RESULTS
        
plt.figure(figsize=(9, 6))
plt.rcParams.update({'font.size': 20})
linestyle='dashed'

plt.plot(Tdata1,Qdata1, label='L=40', linestyle=linestyle, linewidth=1.5, color='cornflowerblue')
plt.plot(Tdata2, Qdata2, label='L=60', linestyle=linestyle, linewidth=1.5, color='royalblue')
plt.plot(Tdata3,Qdata3, label='L=80', linestyle=linestyle, linewidth=1.5, color='midnightblue')
plt.plot(Tdata4,Qdata4, label='L=100', linestyle=linestyle, linewidth=1.5, color='black')
#plt.plot(Tdata5,Qdata5, label='L=120', color='red')

plt.legend(); plt.xlabel('T$[J/k_B]$'); plt.ylabel('Magnetic Susceptibility [$1/J$]')
plt.savefig('MC500000_finescan_magnetic_susceptibility.pdf')

# %%
#IMPORT THE RESULTS

data1 = pa.mat() 
data1.load('specificheat40.csv') 

data2 = pa.mat() 
data2.load('specificheat60.csv') 

data3 = pa.mat() 
data3.load('specificheat80.csv') 

data4 = pa.mat() 
data4.load('specificheat100.csv') 

#data5 = pa.mat() 
#data5.load('test_120.csv') 

#ARRANGE LISTS FOR PLOTTING

Tdata1 = []; Qdata1 = [];

for i in range(len(data1)):
    if i < round(len(data1)/2):
        Tdata1.append(data1[i])
    else:
        Qdata1.append(data1[i])

Tdata2 = []; Qdata2 = [];

for i in range(len(data2)):
    if i < round(len(data2)/2):
        Tdata2.append(data2[i])
    else:
        Qdata2.append(data2[i])
        

Tdata3 = []; Qdata3 = [];

for i in range(len(data3)):
    if i < round(len(data3)/2):
        Tdata3.append(data3[i])
    else:
        Qdata3.append(data3[i])

Tdata4 = []; Qdata4 = [];

for i in range(len(data4)):
    if i < round(len(data4)/2):
        Tdata4.append(data4[i])
    else:
        Qdata4.append(data4[i])
        

#Tdata5 = []; Qdata5 = [];

#for i in range(len(data5)):
#    if i < round(len(data5)/2):
#        Tdata5.append(data5[i])
#    else:
#        Qdata5.append(data5[i])

        
#PLOT THE RESULTS
        
plt.figure(figsize=(9, 6))
plt.rcParams.update({'font.size': 20})
linestyle='dashed'

plt.plot(Tdata1,Qdata1, label='L=40', linestyle=linestyle, linewidth=1.5, color='cornflowerblue')
plt.plot(Tdata2, Qdata2, label='L=60', linestyle=linestyle, linewidth=1.5, color='royalblue')
plt.plot(Tdata3,Qdata3, label='L=80', linestyle=linestyle, linewidth=1.5, color='midnightblue')
plt.plot(Tdata4,Qdata4, label='L=100', linestyle=linestyle, linewidth=1.5, color='black')
#plt.plot(Tdata5,Qdata5, label='L=120', color='red')

plt.legend(); plt.xlabel('T$[J/k_B]$'); plt.ylabel('Specific Heat Capacity $[k_B]$')
plt.savefig('MC500000_finescan_specific_heat_capacity.pdf')
